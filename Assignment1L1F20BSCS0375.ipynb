# %%
import pandas as pd
import numpy as np
df=pd.read_csv('jsrt_metadata.csv')
df
# Out:
#          study_id  subtlety  size age  gender       x       y       state  \
# 0    JPCLN001.png       5.0  15.0  53    Male  1634.0   692.0   malignant
# 1    JPCLN002.png       5.0  30.0  78  Female  1614.0  1090.0      benign
# 2    JPCLN003.png       5.0  30.0  63  Female  1303.0   447.0   malignant
# 3    JPCLN004.png       5.0  14.0  68  Female   606.0   836.0      benign
# 4    JPCLN005.png       5.0  35.0  73  Female  1438.0   692.0   malignant
# ..            ...       ...   ...  ..     ...     ...     ...         ...
# 242  JPCNN089.png       NaN   NaN  50    Male     NaN     NaN  non-nodule
# 243  JPCNN090.png       NaN   NaN  68  Female     NaN     NaN  non-nodule
# 244  JPCNN091.png       NaN   NaN  81    Male     NaN     NaN  non-nodule
# 245  JPCNN092.png       NaN   NaN  70  Female     NaN     NaN  non-nodule
# 246  JPCNN093.png       NaN   NaN  41    Male     NaN     NaN  non-nodule
#
#                position           diagnosis
# 0          l.upper lobe         lung cancer
# 1      l.upper lobe(S5)  pulmonary hematoma
# 2    l.upper lobe(S1+2)         lung cancer
# 3          r.upper lobe   Inflammatory mass
# 4      l.upper lobe(S3)         lung cancer
# ..                  ...                 ...
# 242                 NaN                 NaN
# 243                 NaN                 NaN
# 244                 NaN                 NaN
# 245                 NaN                 NaN
# 246                 NaN                 NaN
#
# [247 rows x 10 columns]

# %%
#Handling All missing Values
df['subtlety']=df['subtlety'].replace(np.nan,df['subtlety'].astype('float').mean())

# %%
df['size']=df['size'].replace(np.nan, df['size'].astype('float').mean())
df
# Out:
#          study_id  subtlety       size age  gender       x       y  \
# 0    JPCLN001.png   5.00000  15.000000  53    Male  1634.0   692.0
# 1    JPCLN002.png   5.00000  30.000000  78  Female  1614.0  1090.0
# 2    JPCLN003.png   5.00000  30.000000  63  Female  1303.0   447.0
# 3    JPCLN004.png   5.00000  14.000000  68  Female   606.0   836.0
# 4    JPCLN005.png   5.00000  35.000000  73  Female  1438.0   692.0
# ..            ...       ...        ...  ..     ...     ...     ...
# 242  JPCNN089.png   2.88961  17.246753  50    Male     NaN     NaN
# 243  JPCNN090.png   2.88961  17.246753  68  Female     NaN     NaN
# 244  JPCNN091.png   2.88961  17.246753  81    Male     NaN     NaN
# 245  JPCNN092.png   2.88961  17.246753  70  Female     NaN     NaN
# 246  JPCNN093.png   2.88961  17.246753  41    Male     NaN     NaN
#
#           state            position           diagnosis
# 0     malignant        l.upper lobe         lung cancer
# 1        benign    l.upper lobe(S5)  pulmonary hematoma
# 2     malignant  l.upper lobe(S1+2)         lung cancer
# 3        benign        r.upper lobe   Inflammatory mass
# 4     malignant    l.upper lobe(S3)         lung cancer
# ..          ...                 ...                 ...
# 242  non-nodule                 NaN                 NaN
# 243  non-nodule                 NaN                 NaN
# 244  non-nodule                 NaN                 NaN
# 245  non-nodule                 NaN                 NaN
# 246  non-nodule                 NaN                 NaN
#
# [247 rows x 10 columns]

# %%
df.isnull().sum()
# Out:
# study_id      0
# subtlety      0
# size          0
# age           0
# gender        0
# x            93
# y            93
# state         0
# position     93
# diagnosis    93
# dtype: int64

# %%
df['x']=df['x'].replace(np.nan, df['x'].astype('float').mean())
df['y']=df['y'].replace(np.nan, df['y'].astype('float').mean())
df['state']=df['state'].replace('non-nodule',np.nan)
df['state']=df['state'].replace(np.nan, df['state'].value_counts().idxmax())
df['position']=df['position'].replace(np.nan, df['position'].value_counts().idxmax())
df['diagnosis']=df['diagnosis'].replace(np.nan, df['diagnosis'].value_counts().idxmax())
df
# Out:
#          study_id  subtlety       size age  gender            x            y  \
# 0    JPCLN001.png   5.00000  15.000000  53    Male  1634.000000   692.000000
# 1    JPCLN002.png   5.00000  30.000000  78  Female  1614.000000  1090.000000
# 2    JPCLN003.png   5.00000  30.000000  63  Female  1303.000000   447.000000
# 3    JPCLN004.png   5.00000  14.000000  68  Female   606.000000   836.000000
# 4    JPCLN005.png   5.00000  35.000000  73  Female  1438.000000   692.000000
# ..            ...       ...        ...  ..     ...          ...          ...
# 242  JPCNN089.png   2.88961  17.246753  50    Male   937.324675   868.623377
# 243  JPCNN090.png   2.88961  17.246753  68  Female   937.324675   868.623377
# 244  JPCNN091.png   2.88961  17.246753  81    Male   937.324675   868.623377
# 245  JPCNN092.png   2.88961  17.246753  70  Female   937.324675   868.623377
# 246  JPCNN093.png   2.88961  17.246753  41    Male   937.324675   868.623377
#
#          state            position           diagnosis
# 0    malignant        l.upper lobe         lung cancer
# 1       benign    l.upper lobe(S5)  pulmonary hematoma
# 2    malignant  l.upper lobe(S1+2)         lung cancer
# 3       benign        r.upper lobe   Inflammatory mass
# 4    malignant    l.upper lobe(S3)         lung cancer
# ..         ...                 ...                 ...
# 242  malignant    r.upper lobe(S2)         lung cancer
# 243  malignant    r.upper lobe(S2)         lung cancer
# 244  malignant    r.upper lobe(S2)         lung cancer
# 245  malignant    r.upper lobe(S2)         lung cancer
# 246  malignant    r.upper lobe(S2)         lung cancer
#
# [247 rows x 10 columns]

# %%
#Find the total number of patients of each disease (diagnosis) and plot in histogram.
import matplotlib as plt
from matplotlib import pyplot
plt.pyplot.hist(df['diagnosis'].value_counts())
# Out:
# (array([30.,  1.,  0.,  0.,  0.,  0.,  0.,  0.,  0.,  1.]),
#  array([  1. ,  15.8,  30.6,  45.4,  60.2,  75. ,  89.8, 104.6, 119.4,
#         134.2, 149. ]),
#  <BarContainer object of 10 artists>)

# %%
#Find the total number of patients of each disease (diagnosis) with respect to the disease state(malignant or benign) and plot in piechart
plt.pyplot.pie(df['state'].value_counts(), autopct='%1.1f%%',labels=['Malignant', 'Benign'])
# Out:
# ([<matplotlib.patches.Wedge at 0x1e649b052b0>,
#   <matplotlib.patches.Wedge at 0x1e649b059d0>],
#  [Text(-0.850588847327074, 0.6974945252851811, 'Malignant'),
#   Text(0.8505889126312205, -0.6974944456473027, 'Benign')],
#  [Text(-0.4639575530874948, 0.38045155924646235, '78.1%'),
#   Text(0.4639575887079384, -0.3804515158076196, '21.9%')])

# %%
plt.pyplot.pie(df['gender'].value_counts(), autopct='%1.1f%%',labels=['Male', 'Female'])
# Out:
# ([<matplotlib.patches.Wedge at 0x1e649b54d90>,
#   <matplotlib.patches.Wedge at 0x1e649b62550>],
#  [Text(-0.06292471903937313, 1.098198743276378, 'Male'),
#   Text(0.06292471903937276, -1.098198743276378, 'Female')],
#  [Text(-0.03432257402147625, 0.5990174963325697, '51.8%'),
#   Text(0.034322574021476045, -0.5990174963325697, '48.2%')])

# %%
lungocc=0
itr=0
df['diagnosis'].value_counts()
# Out:
# lung cancer                                       149
# lung cancer(adenocarcinoma)                        23
# tuberculoma                                        14
# granuloma                                           8
# lung cancer(bronchioloalveolar cell carcinoma)      7
# unknown                                             4
# metastasis of colon cancer                          4
# inflammatory mass                                   4
# pulmonary tuberculosis                              3
# lung abscess                                        2
# Cryptococcosis                                      2
# lung cancer(squamous cell carcinoma)                2
# Inflammatory mass                                   2
# pulmonary hematoma                                  2
# susp. inflammatory mass                             2
# hamartoma                                           2
# sclerosing hemangioma                               2
# lung cancer(large cell carcinoma)                   1
# susp. hamartoma                                     1
# metastasis of uterine cancer                        1
# organizing pneumonia                                1
# metastasis of ovarian cancer                        1
# metastatic lung cancer                              1
# lung canceror metastasis                            1
# pneumonia                                           1
# calcified granuloma                                 1
# lung cancer(adenosquamous carcinoma)                1
# lung cancer(small cell carcinoma)                   1
# susp.tuberculoma                                    1
# organiging pneumonia                                1
# susp. sclerosing hemangioma                         1
# susp. lung metastasis                               1
# Name: diagnosis, dtype: int64

# %%
lst=df['diagnosis']
lst=list(set(lst))
maligList=[0]*len(lst)
benList=[0]*len(lst)
lstitr=0
occ=0
for i in lst:
    itr=0
    for u in df['diagnosis']:
        if i==u:
            if df['state'][itr]=='malignant':
                occ+=1
        itr+=1  
    maligList[lstitr]=occ
    lstitr+=1
    occ=0
    
plt.pyplot.pie(maligList,autopct='%1.0f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x1e64cec42e0>,
#   <matplotlib.patches.Wedge at 0x1e64cec4a30>,
#   <matplotlib.patches.Wedge at 0x1e64cec4fd0>,
#   <matplotlib.patches.Wedge at 0x1e64ced2790>,
#   <matplotlib.patches.Wedge at 0x1e64ced2eb0>,
#   <matplotlib.patches.Wedge at 0x1e64cee0610>,
#   <matplotlib.patches.Wedge at 0x1e64cee0d30>,
#   <matplotlib.patches.Wedge at 0x1e64ceeb4c0>,
#   <matplotlib.patches.Wedge at 0x1e64ceebbe0>,
#   <matplotlib.patches.Wedge at 0x1e64cef7340>,
#   <matplotlib.patches.Wedge at 0x1e64ce90250>,
#   <matplotlib.patches.Wedge at 0x1e64cf04190>,
#   <matplotlib.patches.Wedge at 0x1e64cf048b0>,
#   <matplotlib.patches.Wedge at 0x1e64cf04fd0>,
#   <matplotlib.patches.Wedge at 0x1e64cf10730>,
#   <matplotlib.patches.Wedge at 0x1e64cf10e50>,
#   <matplotlib.patches.Wedge at 0x1e64cf1d5b0>,
#   <matplotlib.patches.Wedge at 0x1e64cf1dcd0>,
#   <matplotlib.patches.Wedge at 0x1e64cf2a460>,
#   <matplotlib.patches.Wedge at 0x1e64cf2ab80>,
#   <matplotlib.patches.Wedge at 0x1e64cf362e0>,
#   <matplotlib.patches.Wedge at 0x1e64cf36a00>,
#   <matplotlib.patches.Wedge at 0x1e64cf43190>,
#   <matplotlib.patches.Wedge at 0x1e64cf438b0>,
#   <matplotlib.patches.Wedge at 0x1e64cf43fd0>,
#   <matplotlib.patches.Wedge at 0x1e64cf51730>,
#   <matplotlib.patches.Wedge at 0x1e64cf51e50>,
#   <matplotlib.patches.Wedge at 0x1e64cf5f5b0>,
#   <matplotlib.patches.Wedge at 0x1e64cf5fcd0>,
#   <matplotlib.patches.Wedge at 0x1e64cf6c430>,
#   <matplotlib.patches.Wedge at 0x1e64cf6cb50>,
#   <matplotlib.patches.Wedge at 0x1e64cf7b2b0>],
#  [Text(1.099854273610275, 0.017904659204087993, ''),
#   Text(1.0986886941496694, 0.05369500300488356, ''),
#   Text(1.0976691499073101, 0.07157120469688366, ''),
#   Text(1.0976691499073101, 0.07157120469688366, ''),
#   Text(1.0976691499073101, 0.07157120469688366, ''),
#   Text(1.0976691499073101, 0.07157120469688366, ''),
#   Text(1.0824137776162157, 0.19590919842262083, ''),
#   Text(1.053120426224517, 0.31770641773293107, ''),
#   Text(1.0478096147934997, 0.3348059305721722, ''),
#   Text(1.0422211787946947, 0.35181673421228443, ''),
#   Text(0.8413686854691798, 0.7085892569831022, ''),
#   Text(0.5239564810335872, 0.9671967772810767, ''),
#   Text(0.5239564810335872, 0.9671967772810767, ''),
#   Text(0.5239564810335872, 0.9671967772810767, ''),
#   Text(0.5239564810335872, 0.9671967772810767, ''),
#   Text(-1.0302174583723334, -0.3855541316921005, ''),
#   Text(1.030217363614572, -0.3855543848888782, ''),
#   Text(1.030217363614572, -0.3855543848888782, ''),
#   Text(1.030217363614572, -0.3855543848888782, ''),
#   Text(1.030217363614572, -0.3855543848888782, ''),
#   Text(1.030217363614572, -0.3855543848888782, ''),
#   Text(1.0531203723102, -0.31770659644588095, ''),
#   Text(1.0715603524287143, -0.24851239627602076, ''),
#   Text(1.0754634207394245, -0.23103772560223948, ''),
#   Text(1.0790815374108882, -0.21350183984910764, ''),
#   Text(1.0790815374108882, -0.21350183984910764, ''),
#   Text(1.0790815374108882, -0.21350183984910764, ''),
#   Text(1.0824137437975048, -0.19590938527357515, ''),
#   Text(1.088216970137484, -0.1605734283896146, ''),
#   Text(1.0928669497433197, -0.1250673025164155, ''),
#   Text(1.0976691373429561, -0.0715713973928881, ''),
#   Text(1.0998542704670922, -0.017904852283692266, '')],
#  [Text(0.5999205128783317, 0.00976617774768436, '1%'),
#   Text(0.599284742263456, 0.02928818345720921, '1%'),
#   Text(0.5987286272221691, 0.0390388389255729, '0%'),
#   Text(0.5987286272221691, 0.0390388389255729, '0%'),
#   Text(0.5987286272221691, 0.0390388389255729, '0%'),
#   Text(0.5987286272221691, 0.0390388389255729, '0%'),
#   Text(0.5904075150633903, 0.10685956277597498, '4%'),
#   Text(0.574429323395191, 0.17329440967250784, '0%'),
#   Text(0.5715325171600906, 0.18262141667573026, '1%'),
#   Text(0.5684842793425607, 0.1919000368430642, '0%'),
#   Text(0.4589283738922798, 0.38650323108169204, '12%'),
#   Text(0.28579444420013844, 0.5275618785169508, '0%'),
#   Text(0.28579444420013844, 0.5275618785169508, '0%'),
#   Text(0.28579444420013844, 0.5275618785169508, '0%'),
#   Text(0.28579444420013844, 0.5275618785169508, '0%'),
#   Text(-0.5619367954758182, -0.2103022536502366, '77%'),
#   Text(0.5619367437897664, -0.2103023917575699, '0%'),
#   Text(0.5619367437897664, -0.2103023917575699, '0%'),
#   Text(0.5619367437897664, -0.2103023917575699, '0%'),
#   Text(0.5619367437897664, -0.2103023917575699, '0%'),
#   Text(0.5619367437897664, -0.2103023917575699, '0%'),
#   Text(0.5744292939873817, -0.1732945071522987, '2%'),
#   Text(0.5844874649611168, -0.13555221615055676, '0%'),
#   Text(0.5866164113124133, -0.1260205776012215, '1%'),
#   Text(0.5885899294968481, -0.11645554900860415, '0%'),
#   Text(0.5885899294968481, -0.11645554900860415, '0%'),
#   Text(0.5885899294968481, -0.11645554900860415, '0%'),
#   Text(0.5904074966168207, -0.10685966469467735, '1%'),
#   Text(0.5935728928022639, -0.08758550639433522, '1%'),
#   Text(0.5961092453145379, -0.06821852864531755, '1%'),
#   Text(0.5987286203688851, -0.03903894403248442, '1%'),
#   Text(0.5999205111638684, -0.009766283063832143, '1%')])

# %%
lstitr=0   
for i in lst:
    itr=0
    for u in df['diagnosis']:
        if i==u:
            if df['state'][itr]=='benign':
                occ+=1
        itr+=1  
    benList[lstitr]=occ
    lstitr+=1
    occ=0

plt.pyplot.pie(benList,autopct='%1.0f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x1e64cfbc9d0>,
#   <matplotlib.patches.Wedge at 0x1e64cfcc1c0>,
#   <matplotlib.patches.Wedge at 0x1e64cfcc8e0>,
#   <matplotlib.patches.Wedge at 0x1e64cfccfd0>,
#   <matplotlib.patches.Wedge at 0x1e64cfd9760>,
#   <matplotlib.patches.Wedge at 0x1e64cfd9e80>,
#   <matplotlib.patches.Wedge at 0x1e64cfe55e0>,
#   <matplotlib.patches.Wedge at 0x1e64cfe5d00>,
#   <matplotlib.patches.Wedge at 0x1e64cff1460>,
#   <matplotlib.patches.Wedge at 0x1e64cff1b80>,
#   <matplotlib.patches.Wedge at 0x1e64cf98910>,
#   <matplotlib.patches.Wedge at 0x1e64cffe9d0>,
#   <matplotlib.patches.Wedge at 0x1e64d00a130>,
#   <matplotlib.patches.Wedge at 0x1e64d00a850>,
#   <matplotlib.patches.Wedge at 0x1e64d00af70>,
#   <matplotlib.patches.Wedge at 0x1e64d01a6d0>,
#   <matplotlib.patches.Wedge at 0x1e64d01adf0>,
#   <matplotlib.patches.Wedge at 0x1e64d026550>,
#   <matplotlib.patches.Wedge at 0x1e64d026c70>,
#   <matplotlib.patches.Wedge at 0x1e64d0353d0>,
#   <matplotlib.patches.Wedge at 0x1e64d035af0>,
#   <matplotlib.patches.Wedge at 0x1e64d043250>,
#   <matplotlib.patches.Wedge at 0x1e64d043970>,
#   <matplotlib.patches.Wedge at 0x1e64d04f0d0>,
#   <matplotlib.patches.Wedge at 0x1e64d04f7f0>,
#   <matplotlib.patches.Wedge at 0x1e64d04ff10>,
#   <matplotlib.patches.Wedge at 0x1e64d05c670>,
#   <matplotlib.patches.Wedge at 0x1e64d05cd90>,
#   <matplotlib.patches.Wedge at 0x1e64d06a4f0>,
#   <matplotlib.patches.Wedge at 0x1e64d06ac10>,
#   <matplotlib.patches.Wedge at 0x1e64d077370>,
#   <matplotlib.patches.Wedge at 0x1e64d077a90>],
#  [Text(1.1, 0.0, ''),
#   Text(1.1, 0.0, ''),
#   Text(1.0981389740706715, 0.06395931227751966, ''),
#   Text(1.070349357197973, 0.2536774596724868, ''),
#   Text(1.0100377162463376, 0.4356877457077294, ''),
#   Text(0.9526279420172694, 0.550000003716311, ''),
#   Text(0.9190365899341553, 0.6044598798615171, ''),
#   Text(0.7548657968002127, 0.8001110103111819, ''),
#   Text(0.5499999925673781, 0.9526279484541089, ''),
#   Text(0.4356877338869099, 1.0100377213453413, ''),
#   Text(0.3154835459332108, 1.0537884665555075, ''),
#   Text(0.25367744714581936, 1.0703493601668477, ''),
#   Text(-0.65687444475379, 0.8823355165861797, ''),
#   Text(-1.0999999999999999, 2.5747358557800545e-08, ''),
#   Text(-1.0703493631357222, -0.2536774346191518, ''),
#   Text(-1.033661890692157, -0.3762221361519223, ''),
#   Text(-1.010037726444345, -0.4356877220660903, ''),
#   Text(-0.9190366040825597, -0.6044598583499129, ''),
#   Text(-0.4356877575285492, -1.0100377111473335, ''),
#   Text(0.2536774471458191, -1.0703493601668477, ''),
#   Text(0.49367909012486194, -0.98299590842154, ''),
#   Text(0.5499999925673779, -0.952627948454109, ''),
#   Text(0.6568744447537894, -0.8823355165861799, ''),
#   Text(0.7548657968002127, -0.8001110103111819, ''),
#   Text(0.9190365899341549, -0.6044598798615175, ''),
#   Text(1.070349357197973, -0.25367745967248734, ''),
#   Text(1.0981389740706715, -0.06395931227751976, ''),
#   Text(1.1, -2.6942229581241775e-16, ''),
#   Text(1.1, -2.6942229581241775e-16, ''),
#   Text(1.1, -2.6942229581241775e-16, ''),
#   Text(1.1, -2.6942229581241775e-16, ''),
#   Text(1.1, -2.6942229581241775e-16, '')],
#  [Text(0.6, 0.0, '0%'),
#   Text(0.6, 0.0, '0%'),
#   Text(0.598984894947639, 0.034886897605919814, '2%'),
#   Text(0.5838269221079853, 0.13836952345772005, '4%'),
#   Text(0.5509296634070932, 0.2376478612951251, '2%'),
#   Text(0.5196152411003288, 0.3000000020270787, '2%'),
#   Text(0.50129268541863, 0.32970538901537294, '0%'),
#   Text(0.41174498007284327, 0.4364241874424628, '7%'),
#   Text(0.29999999594584253, 0.519615244611332, '0%'),
#   Text(0.23764785484740536, 0.5509296661883679, '4%'),
#   Text(0.17208193414538772, 0.5747937090302767, '0%'),
#   Text(0.13836951662499236, 0.5838269237273714, '2%'),
#   Text(-0.35829515168388537, 0.4812739181379161, '26%'),
#   Text(-0.5999999999999999, 1.4044013758800295e-08, '4%'),
#   Text(-0.5838269253467575, -0.13836950979226462, '4%'),
#   Text(-0.5638155767411764, -0.20521207426468485, '0%'),
#   Text(-0.5509296689696427, -0.23764784839968559, '2%'),
#   Text(-0.5012926931359416, -0.32970537728177063, '4%'),
#   Text(-0.237647867742845, -0.5509296606258183, '15%'),
#   Text(0.13836951662499222, -0.5838269237273714, '6%'),
#   Text(0.2692795037044701, -0.536179586411749, '2%'),
#   Text(0.2999999959458424, -0.5196152446113321, '0%'),
#   Text(0.3582951516838851, -0.48127391813791626, '4%'),
#   Text(0.41174498007284327, -0.4364241874424628, '0%'),
#   Text(0.5012926854186299, -0.3297053890153731, '7%'),
#   Text(0.5838269221079851, -0.13836952345772036, '4%'),
#   Text(0.598984894947639, -0.03488689760591987, '2%'),
#   Text(0.6, -1.4695761589768238e-16, '0%'),
#   Text(0.6, -1.4695761589768238e-16, '0%'),
#   Text(0.6, -1.4695761589768238e-16, '0%'),
#   Text(0.6, -1.4695761589768238e-16, '0%'),
#   Text(0.6, -1.4695761589768238e-16, '0%')])

# %%
Mlist=[0]*len(lst)
Flist=[0]*len(lst)
lstitr=0   
for i in lst:
    itr=0
    for u in df['diagnosis']:
        if i==u:
            if df['gender'][itr]=='Male':
                occ+=1
        itr+=1  
    Mlist[lstitr]=occ
    lstitr+=1
    occ=0

plt.pyplot.pie(Mlist,autopct='%1.0f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x1e64d22cd30>,
#   <matplotlib.patches.Wedge at 0x1e64d23c4f0>,
#   <matplotlib.patches.Wedge at 0x1e64d23cc10>,
#   <matplotlib.patches.Wedge at 0x1e64d246370>,
#   <matplotlib.patches.Wedge at 0x1e64d246a90>,
#   <matplotlib.patches.Wedge at 0x1e64d2531f0>,
#   <matplotlib.patches.Wedge at 0x1e64d253940>,
#   <matplotlib.patches.Wedge at 0x1e64d2610a0>,
#   <matplotlib.patches.Wedge at 0x1e64d2617c0>,
#   <matplotlib.patches.Wedge at 0x1e64d261ee0>,
#   <matplotlib.patches.Wedge at 0x1e64d208910>,
#   <matplotlib.patches.Wedge at 0x1e64d26ed30>,
#   <matplotlib.patches.Wedge at 0x1e64d27d490>,
#   <matplotlib.patches.Wedge at 0x1e64d27dbb0>,
#   <matplotlib.patches.Wedge at 0x1e64d28b310>,
#   <matplotlib.patches.Wedge at 0x1e64d28ba30>,
#   <matplotlib.patches.Wedge at 0x1e64d297190>,
#   <matplotlib.patches.Wedge at 0x1e64d2978b0>,
#   <matplotlib.patches.Wedge at 0x1e64d297fd0>,
#   <matplotlib.patches.Wedge at 0x1e64d2a4730>,
#   <matplotlib.patches.Wedge at 0x1e64d2a4e50>,
#   <matplotlib.patches.Wedge at 0x1e64d2b35b0>,
#   <matplotlib.patches.Wedge at 0x1e64d2b3cd0>,
#   <matplotlib.patches.Wedge at 0x1e64d2bf430>,
#   <matplotlib.patches.Wedge at 0x1e64d2bfb50>,
#   <matplotlib.patches.Wedge at 0x1e64d2ce2b0>,
#   <matplotlib.patches.Wedge at 0x1e64d2ce9d0>,
#   <matplotlib.patches.Wedge at 0x1e64d2b6130>,
#   <matplotlib.patches.Wedge at 0x1e64d2b6850>,
#   <matplotlib.patches.Wedge at 0x1e64d2b6f70>,
#   <matplotlib.patches.Wedge at 0x1e64d2e86d0>,
#   <matplotlib.patches.Wedge at 0x1e64d2e8df0>],
#  [Text(1.1, 0.0, ''),
#   Text(1.1, 0.0, ''),
#   Text(1.0996166960164684, 0.02903656043380658, ''),
#   Text(1.0965518667468876, 0.08702875119129332, ''),
#   Text(1.090430750437474, 0.14477837718515613, ''),
#   Text(1.086229084483789, 0.17351189014447835, ''),
#   Text(1.0690963709296535, 0.2589072221183579, ''),
#   Text(1.0257194471471633, 0.3973658462224927, ''),
#   Text(1.0033188934208301, 0.4509447838758101, ''),
#   Text(1.0033188934208301, 0.4509447838758101, ''),
#   Text(0.8864924389190937, 0.6512535264697438, ''),
#   Text(0.7083014592393247, 0.8416109807027492, ''),
#   Text(0.46414882717176587, 0.9972792318278139, ''),
#   Text(0.21637911919247327, 1.0785082645846946, ''),
#   Text(0.18783447430037062, 1.0838441817273845, ''),
#   Text(-1.0618894600426647, -0.287037932424093, ''),
#   Text(0.708301661157403, -0.8416108107680554, ''),
#   Text(0.7517308841321194, -0.803057082555121, ''),
#   Text(0.8864925913559583, -0.6512533189711959, ''),
#   Text(1.0148729065942752, -0.4243029383128141, ''),
#   Text(1.0452612127109706, -0.3426791461440153, ''),
#   Text(1.053942640847109, -0.3149681091860284, ''),
#   Text(1.0618895591420647, -0.28703756580815615, ''),
#   Text(1.069096429258675, -0.2589069812622883, ''),
#   Text(1.0755582286114407, -0.23059596021227233, ''),
#   Text(1.0755582286114407, -0.23059596021227233, ''),
#   Text(1.0755582286114407, -0.23059596021227233, ''),
#   Text(1.0755582286114407, -0.23059596021227233, ''),
#   Text(1.0812704538668483, -0.20212423307109956, ''),
#   Text(1.086229124081815, -0.17351164225046417, ''),
#   Text(1.093872503850566, -0.11594371617165702, ''),
#   Text(1.0996167026430248, -0.02903630948453912, '')],
#  [Text(0.6, 0.0, '0%'),
#   Text(0.6, 0.0, '0%'),
#   Text(0.5997909250998917, 0.015838123872985405, '1%'),
#   Text(0.5981192000437568, 0.047470227922523624, '1%'),
#   Text(0.5947804093295312, 0.07897002391917607, '1%'),
#   Text(0.5924885915366122, 0.09464284916971545, '0%'),
#   Text(0.5831434750525383, 0.14122212115546795, '3%'),
#   Text(0.5594833348075436, 0.21674500703045055, '2%'),
#   Text(0.5472648509568163, 0.24596988211407822, '0%'),
#   Text(0.5472648509568163, 0.24596988211407822, '0%'),
#   Text(0.4835413303195056, 0.35522919625622384, '7%'),
#   Text(0.3863462504941771, 0.45906053492877225, '1%'),
#   Text(0.2531720875482359, 0.5439704900878984, '8%'),
#   Text(0.1180249741049854, 0.5882772352280152, '0%'),
#   Text(0.10245516780020214, 0.5911877354876641, '1%'),
#   Text(-0.5792124327505443, -0.15656614495859614, '63%'),
#   Text(0.38634636063131067, -0.4590604422371211, '1%'),
#   Text(0.4100350277084287, -0.4380311359391568, '1%'),
#   Text(0.4835414134668863, -0.3552290830751977, '5%'),
#   Text(0.5535670399605137, -0.231437966352444, '3%'),
#   Text(0.5701424796605293, -0.1869158978967356, '0%'),
#   Text(0.574877804098423, -0.17180078682874275, '1%'),
#   Text(0.5792124868047626, -0.15656594498626697, '0%'),
#   Text(0.5831435068683681, -0.14122198977942996, '1%'),
#   Text(0.5866681246971495, -0.12577961466123944, '0%'),
#   Text(0.5866681246971495, -0.12577961466123944, '0%'),
#   Text(0.5866681246971495, -0.12577961466123944, '0%'),
#   Text(0.5866681246971495, -0.12577961466123944, '0%'),
#   Text(0.5897838839273717, -0.1102495816751452, '1%'),
#   Text(0.5924886131355354, -0.09464271395479863, '0%'),
#   Text(0.5966577293730358, -0.06324202700272201, '2%'),
#   Text(0.5997909287143771, -0.015837986991566792, '1%')])

# %%
lstitr=0   
for i in lst:
    itr=0
    for u in df['diagnosis']:
        if i==u:
            if df['gender'][itr]=='Female':
                occ+=1
        itr+=1  
    Flist[lstitr]=occ
    lstitr+=1
    occ=0

plt.pyplot.pie(Flist,autopct='%1.0f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x1e64d336850>,
#   <matplotlib.patches.Wedge at 0x1e64d336fd0>,
#   <matplotlib.patches.Wedge at 0x1e64d346760>,
#   <matplotlib.patches.Wedge at 0x1e64d346e80>,
#   <matplotlib.patches.Wedge at 0x1e64d3515e0>,
#   <matplotlib.patches.Wedge at 0x1e64d351d00>,
#   <matplotlib.patches.Wedge at 0x1e64d35f460>,
#   <matplotlib.patches.Wedge at 0x1e64d35fb80>,
#   <matplotlib.patches.Wedge at 0x1e64d36a2e0>,
#   <matplotlib.patches.Wedge at 0x1e64d36aa00>,
#   <matplotlib.patches.Wedge at 0x1e64d312790>,
#   <matplotlib.patches.Wedge at 0x1e64d378850>,
#   <matplotlib.patches.Wedge at 0x1e64d378f70>,
#   <matplotlib.patches.Wedge at 0x1e64d3876d0>,
#   <matplotlib.patches.Wedge at 0x1e64d387df0>,
#   <matplotlib.patches.Wedge at 0x1e64d394550>,
#   <matplotlib.patches.Wedge at 0x1e64d394c70>,
#   <matplotlib.patches.Wedge at 0x1e64d3a33d0>,
#   <matplotlib.patches.Wedge at 0x1e64d3a3af0>,
#   <matplotlib.patches.Wedge at 0x1e64d3b0250>,
#   <matplotlib.patches.Wedge at 0x1e64d3b0970>,
#   <matplotlib.patches.Wedge at 0x1e64d3bc0d0>,
#   <matplotlib.patches.Wedge at 0x1e64d3bc7f0>,
#   <matplotlib.patches.Wedge at 0x1e64d3bcf10>,
#   <matplotlib.patches.Wedge at 0x1e64d3c9670>,
#   <matplotlib.patches.Wedge at 0x1e64d3c9d90>,
#   <matplotlib.patches.Wedge at 0x1e64d3d84f0>,
#   <matplotlib.patches.Wedge at 0x1e64d3d8c10>,
#   <matplotlib.patches.Wedge at 0x1e64d3e5370>,
#   <matplotlib.patches.Wedge at 0x1e64d3e5a90>,
#   <matplotlib.patches.Wedge at 0x1e64d3f41f0>,
#   <matplotlib.patches.Wedge at 0x1e64d3f4910>],
#  [Text(1.098695460774623, 0.053556367252072315, ''),
#   Text(1.0918550891018384, 0.13361311463481645, ''),
#   Text(1.0882777049698038, 0.1601612839161105, ''),
#   Text(1.0840549065298053, 0.18661446789746763, ''),
#   Text(1.0791891981559756, 0.21295697824551954, ''),
#   Text(1.073683465506808, 0.2391731922630368, ''),
#   Text(1.0366818915842637, 0.36781878100672477, ''),
#   Text(0.9720795104932561, 0.5148411650977336, ''),
#   Text(0.9319052854151527, 0.5844249644011651, ''),
#   Text(0.8867589424662288, 0.6508906036778959, ''),
#   Text(0.5499999925673781, 0.9526279484541089, ''),
#   Text(0.1734007119505261, 1.0862468380138333, ''),
#   Text(0.04017420591619505, 1.0992661339179897, ''),
#   Text(-0.14689810874492915, 1.090147212832819, ''),
#   Text(-0.2260818647948836, 1.0765161356946158, ''),
#   Text(-0.9843281979640973, -0.49101730997262505, ''),
#   Text(0.703640207732458, -0.8455119502775958, ''),
#   Text(0.7240206390801521, -0.8281268708271508, ''),
#   Text(0.7825385386981267, -0.77306754908753, ''),
#   Text(0.8192492999258449, -0.7340508051701962, ''),
#   Text(0.8368812566600236, -0.7138835775188697, ''),
#   Text(0.9023457561328517, -0.6291042333262686, ''),
#   Text(0.9720794381888833, -0.514841301616707, ''),
#   Text(0.9959929964330827, -0.4669025070143118, ''),
#   Text(1.036681839927734, -0.3678189265984668, ''),
#   Text(1.079189168248258, -0.21295712980699505, ''),
#   Text(1.0918550703371839, -0.1336132679750917, ''),
#   Text(1.097065500775131, -0.08029499990043772, ''),
#   Text(1.0986954532531488, -0.05355652155301162, ''),
#   Text(1.0996738130702255, -0.02678628095856233, ''),
#   Text(1.0999999999999892, -1.544841498309619e-07, ''),
#   Text(1.0999999999999892, -1.544841498309619e-07, '')],
#  [Text(0.5992884331497943, 0.029212563955675806, '2%'),
#   Text(0.5955573213282754, 0.07287988070989987, '1%'),
#   Text(0.5936060208926202, 0.08736070031787846, '0%'),
#   Text(0.5913026762889847, 0.10178970976225506, '1%'),
#   Text(0.5886486535396229, 0.11615835177028336, '0%'),
#   Text(0.585645526640077, 0.13045810487074733, '1%'),
#   Text(0.5654628499550529, 0.20062842600366804, '3%'),
#   Text(0.530225187541776, 0.28082245368967285, '2%'),
#   Text(0.5083119738628105, 0.31877725330972634, '1%'),
#   Text(0.4836866958906702, 0.3550312383697613, '2%'),
#   Text(0.29999999594584253, 0.519615244611332, '12%'),
#   Text(0.09458220651846876, 0.5924982752802727, '0%'),
#   Text(0.02191320322701548, 0.5995997094098124, '4%'),
#   Text(-0.08012624113359772, 0.5946257524542647, '2%'),
#   Text(-0.12331738079720922, 0.5871906194697903, '1%'),
#   Text(-0.5369062897985984, -0.2678276236214318, '57%'),
#   Text(0.3838037496722497, -0.4611883365150522, '0%'),
#   Text(0.39492034858917385, -0.45170556590571853, '1%'),
#   Text(0.4268392029262509, -0.4216732085931981, '2%'),
#   Text(0.4468632545050063, -0.4003913482746524, '0%'),
#   Text(0.4564806854509219, -0.38939104228301974, '1%'),
#   Text(0.4921885942542827, -0.3431477636325101, '2%'),
#   Text(0.5302251481030272, -0.28082252815456743, '2%'),
#   Text(0.5432689071453177, -0.2546740947350791, '0%'),
#   Text(0.565462821778764, -0.2006285054173455, '3%'),
#   Text(0.5886486372263224, -0.1161584344401791, '2%'),
#   Text(0.5955573110930092, -0.07287996435005002, '1%'),
#   Text(0.5983993640591623, -0.04379727267296602, '1%'),
#   Text(0.5992884290471719, -0.029212648119824512, '0%'),
#   Text(0.5998220798564866, -0.01461069870467036, '1%'),
#   Text(0.5999999999999941, -8.426408172597922e-08, '0%'),
#   Text(0.5999999999999941, -8.426408172597922e-08, '0%')])
