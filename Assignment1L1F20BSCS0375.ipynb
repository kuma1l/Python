# %%
import pandas as pd
import numpy as np
df=pd.read_csv('jsrt_metadata.csv')
df
# Out:
#          study_id  subtlety  size age  gender       x       y       state  \
# 0    JPCLN001.png       5.0  15.0  53    Male  1634.0   692.0   malignant
# 1    JPCLN002.png       5.0  30.0  78  Female  1614.0  1090.0      benign
# 2    JPCLN003.png       5.0  30.0  63  Female  1303.0   447.0   malignant
# 3    JPCLN004.png       5.0  14.0  68  Female   606.0   836.0      benign
# 4    JPCLN005.png       5.0  35.0  73  Female  1438.0   692.0   malignant
# ..            ...       ...   ...  ..     ...     ...     ...         ...
# 242  JPCNN089.png       NaN   NaN  50    Male     NaN     NaN  non-nodule
# 243  JPCNN090.png       NaN   NaN  68  Female     NaN     NaN  non-nodule
# 244  JPCNN091.png       NaN   NaN  81    Male     NaN     NaN  non-nodule
# 245  JPCNN092.png       NaN   NaN  70  Female     NaN     NaN  non-nodule
# 246  JPCNN093.png       NaN   NaN  41    Male     NaN     NaN  non-nodule
#
#                position           diagnosis
# 0          l.upper lobe         lung cancer
# 1      l.upper lobe(S5)  pulmonary hematoma
# 2    l.upper lobe(S1+2)         lung cancer
# 3          r.upper lobe   Inflammatory mass
# 4      l.upper lobe(S3)         lung cancer
# ..                  ...                 ...
# 242                 NaN                 NaN
# 243                 NaN                 NaN
# 244                 NaN                 NaN
# 245                 NaN                 NaN
# 246                 NaN                 NaN
#
# [247 rows x 10 columns]

# %%
#Handling All missing Values
df['subtlety']=df['subtlety'].replace(np.nan,df['subtlety'].astype('float').mean())

# %%
df['size']=df['size'].replace(np.nan, df['size'].astype('float').mean())
df
# Out:
#          study_id  subtlety       size age  gender       x       y  \
# 0    JPCLN001.png   5.00000  15.000000  53    Male  1634.0   692.0
# 1    JPCLN002.png   5.00000  30.000000  78  Female  1614.0  1090.0
# 2    JPCLN003.png   5.00000  30.000000  63  Female  1303.0   447.0
# 3    JPCLN004.png   5.00000  14.000000  68  Female   606.0   836.0
# 4    JPCLN005.png   5.00000  35.000000  73  Female  1438.0   692.0
# ..            ...       ...        ...  ..     ...     ...     ...
# 242  JPCNN089.png   2.88961  17.246753  50    Male     NaN     NaN
# 243  JPCNN090.png   2.88961  17.246753  68  Female     NaN     NaN
# 244  JPCNN091.png   2.88961  17.246753  81    Male     NaN     NaN
# 245  JPCNN092.png   2.88961  17.246753  70  Female     NaN     NaN
# 246  JPCNN093.png   2.88961  17.246753  41    Male     NaN     NaN
#
#           state            position           diagnosis
# 0     malignant        l.upper lobe         lung cancer
# 1        benign    l.upper lobe(S5)  pulmonary hematoma
# 2     malignant  l.upper lobe(S1+2)         lung cancer
# 3        benign        r.upper lobe   Inflammatory mass
# 4     malignant    l.upper lobe(S3)         lung cancer
# ..          ...                 ...                 ...
# 242  non-nodule                 NaN                 NaN
# 243  non-nodule                 NaN                 NaN
# 244  non-nodule                 NaN                 NaN
# 245  non-nodule                 NaN                 NaN
# 246  non-nodule                 NaN                 NaN
#
# [247 rows x 10 columns]

# %%
df.isnull().sum()
# Out:
# study_id      0
# subtlety      0
# size          0
# age           0
# gender        0
# x            93
# y            93
# state         0
# position     93
# diagnosis    93
# dtype: int64

# %%
df['x']=df['x'].replace(np.nan, df['x'].astype('float').mean())
df['y']=df['y'].replace(np.nan, df['y'].astype('float').mean())
df['state']=df['state'].replace('non-nodule',np.nan)
df['state']=df['state'].replace(np.nan, df['state'].value_counts().idxmax())
df['position']=df['position'].replace(np.nan, df['position'].value_counts().idxmax())
df['diagnosis']=df['diagnosis'].replace(np.nan, df['diagnosis'].value_counts().idxmax())
df
# Out:
#          study_id  subtlety       size age  gender            x            y  \
# 0    JPCLN001.png   5.00000  15.000000  53    Male  1634.000000   692.000000
# 1    JPCLN002.png   5.00000  30.000000  78  Female  1614.000000  1090.000000
# 2    JPCLN003.png   5.00000  30.000000  63  Female  1303.000000   447.000000
# 3    JPCLN004.png   5.00000  14.000000  68  Female   606.000000   836.000000
# 4    JPCLN005.png   5.00000  35.000000  73  Female  1438.000000   692.000000
# ..            ...       ...        ...  ..     ...          ...          ...
# 242  JPCNN089.png   2.88961  17.246753  50    Male   937.324675   868.623377
# 243  JPCNN090.png   2.88961  17.246753  68  Female   937.324675   868.623377
# 244  JPCNN091.png   2.88961  17.246753  81    Male   937.324675   868.623377
# 245  JPCNN092.png   2.88961  17.246753  70  Female   937.324675   868.623377
# 246  JPCNN093.png   2.88961  17.246753  41    Male   937.324675   868.623377
#
#          state            position           diagnosis
# 0    malignant        l.upper lobe         lung cancer
# 1       benign    l.upper lobe(S5)  pulmonary hematoma
# 2    malignant  l.upper lobe(S1+2)         lung cancer
# 3       benign        r.upper lobe   Inflammatory mass
# 4    malignant    l.upper lobe(S3)         lung cancer
# ..         ...                 ...                 ...
# 242  malignant    r.upper lobe(S2)         lung cancer
# 243  malignant    r.upper lobe(S2)         lung cancer
# 244  malignant    r.upper lobe(S2)         lung cancer
# 245  malignant    r.upper lobe(S2)         lung cancer
# 246  malignant    r.upper lobe(S2)         lung cancer
#
# [247 rows x 10 columns]

# %%
#Find the total number of patients of each disease (diagnosis) and plot in histogram.
import matplotlib as plt
from matplotlib import pyplot
plt.pyplot.hist(df['diagnosis'])
# Out:
# (array([167.,  33.,  13.,   5.,   8.,   7.,   3.,   3.,   4.,   4.]),
#  array([ 0. ,  3.1,  6.2,  9.3, 12.4, 15.5, 18.6, 21.7, 24.8, 27.9, 31. ]),
#  <BarContainer object of 10 artists>)

# %%
#Find the total number of patients of each disease (diagnosis) with respect to the disease state(malignant or benign) and plot in piechart
plt.pyplot.pie(df['state'].value_counts(), autopct='%1.1f%%',labels=['Malignant', 'Benign'])
# Out:
# ([<matplotlib.patches.Wedge at 0x2c2a063dd30>,
#   <matplotlib.patches.Wedge at 0x2c2a064c4f0>],
#  [Text(-0.850588847327074, 0.6974945252851811, 'Malignant'),
#   Text(0.8505889126312205, -0.6974944456473027, 'Benign')],
#  [Text(-0.4639575530874948, 0.38045155924646235, '78.1%'),
#   Text(0.4639575887079384, -0.3804515158076196, '21.9%')])

# %%
plt.pyplot.pie(df['gender'].value_counts(), autopct='%1.1f%%',labels=['Male', 'Female'])
# Out:
# ([<matplotlib.patches.Wedge at 0x2c2a069a460>,
#   <matplotlib.patches.Wedge at 0x2c2a069ac10>],
#  [Text(-0.06292471903937313, 1.098198743276378, 'Male'),
#   Text(0.06292471903937276, -1.098198743276378, 'Female')],
#  [Text(-0.03432257402147625, 0.5990174963325697, '51.8%'),
#   Text(0.034322574021476045, -0.5990174963325697, '48.2%')])

# %%
lungocc=0
itr=0
df['diagnosis'].value_counts()
# Out:
# lung cancer                                       149
# lung cancer(adenocarcinoma)                        23
# tuberculoma                                        14
# granuloma                                           8
# lung cancer(bronchioloalveolar cell carcinoma)      7
# unknown                                             4
# metastasis of colon cancer                          4
# inflammatory mass                                   4
# pulmonary tuberculosis                              3
# lung abscess                                        2
# Cryptococcosis                                      2
# lung cancer(squamous cell carcinoma)                2
# Inflammatory mass                                   2
# pulmonary hematoma                                  2
# susp. inflammatory mass                             2
# hamartoma                                           2
# sclerosing hemangioma                               2
# lung cancer(large cell carcinoma)                   1
# susp. hamartoma                                     1
# metastasis of uterine cancer                        1
# organizing pneumonia                                1
# metastasis of ovarian cancer                        1
# metastatic lung cancer                              1
# lung canceror metastasis                            1
# pneumonia                                           1
# calcified granuloma                                 1
# lung cancer(adenosquamous carcinoma)                1
# lung cancer(small cell carcinoma)                   1
# susp.tuberculoma                                    1
# organiging pneumonia                                1
# susp. sclerosing hemangioma                         1
# susp. lung metastasis                               1
# Name: diagnosis, dtype: int64

# %%
#Q2A
lst=df['diagnosis']
lst=list(set(lst))
maligList=[0]*len(lst)
benList=[0]*len(lst)
lstitr=0
occ=0
for i in lst:
    itr=0
    for u in df['diagnosis']:
        if i==u:
            if df['state'][itr]=='malignant':
                occ+=1
        itr+=1  
    maligList[lstitr]=occ
    lstitr+=1
    occ=0
    
plt.pyplot.pie(maligList,autopct='%1.0f%%',labels=lst)
# Out:
# ([<matplotlib.patches.Wedge at 0x2c2a1d60bb0>,
#   <matplotlib.patches.Wedge at 0x2c2a1d6f310>,
#   <matplotlib.patches.Wedge at 0x2c2a1d6fa30>,
#   <matplotlib.patches.Wedge at 0x2c2a1d7c190>,
#   <matplotlib.patches.Wedge at 0x2c2a1d7c8b0>,
#   <matplotlib.patches.Wedge at 0x2c2a1d7cfd0>,
#   <matplotlib.patches.Wedge at 0x2c2a1d8a730>,
#   <matplotlib.patches.Wedge at 0x2c2a1d8ae80>,
#   <matplotlib.patches.Wedge at 0x2c2a1d965e0>,
#   <matplotlib.patches.Wedge at 0x2c2a1d96d00>,
#   <matplotlib.patches.Wedge at 0x2c2a1d3caf0>,
#   <matplotlib.patches.Wedge at 0x2c2a1da4b50>,
#   <matplotlib.patches.Wedge at 0x2c2a1db22b0>,
#   <matplotlib.patches.Wedge at 0x2c2a1db29d0>,
#   <matplotlib.patches.Wedge at 0x2c2a1dbf130>,
#   <matplotlib.patches.Wedge at 0x2c2a1dbf850>,
#   <matplotlib.patches.Wedge at 0x2c2a1dbff70>,
#   <matplotlib.patches.Wedge at 0x2c2a1dce6d0>,
#   <matplotlib.patches.Wedge at 0x2c2a1dcedf0>,
#   <matplotlib.patches.Wedge at 0x2c2a1dda550>,
#   <matplotlib.patches.Wedge at 0x2c2a1ddac70>,
#   <matplotlib.patches.Wedge at 0x2c2a1de63d0>,
#   <matplotlib.patches.Wedge at 0x2c2a1de6af0>,
#   <matplotlib.patches.Wedge at 0x2c2a1df6250>,
#   <matplotlib.patches.Wedge at 0x2c2a1df6970>,
#   <matplotlib.patches.Wedge at 0x2c2a1e020d0>,
#   <matplotlib.patches.Wedge at 0x2c2a1e027f0>,
#   <matplotlib.patches.Wedge at 0x2c2a1e02f10>,
#   <matplotlib.patches.Wedge at 0x2c2a1e0e670>,
#   <matplotlib.patches.Wedge at 0x2c2a1e0ed90>,
#   <matplotlib.patches.Wedge at 0x2c2a1e1d4f0>,
#   <matplotlib.patches.Wedge at 0x2c2a1e1dc10>],
#  [Text(1.1, 0.0, 'susp. hamartoma'),
#   Text(1.1, 0.0, 'tuberculoma'),
#   Text(1.1, 0.0, 'Cryptococcosis'),
#   Text(1.1, 0.0, 'organiging pneumonia'),
#   Text(1.092866971332963, 0.12506711386098496, 'lung cancer(bronchioloalveolar cell carcinoma)'),
#   Text(1.053120426224517, 0.31770641773293107, 'metastasis of colon cancer'),
#   Text(1.0302174290425568, 0.3855542100625341, 'lung abscess'),
#   Text(1.0302174290425568, 0.3855542100625341, 'pulmonary hematoma'),
#   Text(1.0302174290425568, 0.3855542100625341, 'pulmonary tuberculosis'),
#   Text(1.0238052957676138, 0.4022719432898459, 'lung canceror metastasis'),
#   Text(1.0171218980389733, 0.41888309172082433, 'susp. sclerosing hemangioma'),
#   Text(1.0029484638788244, 0.4517680586352984, 'lung cancer(squamous cell carcinoma)'),
#   Text(0.9797004098295543, 0.5001870719838765, 'metastatic lung cancer'),
#   Text(0.9629003914283534, 0.5318109026591352, 'lung cancer(small cell carcinoma)'),
#   Text(0.9541165614548642, 0.5474135430892686, 'sclerosing hemangioma'),
#   Text(0.9541165614548642, 0.5474135430892686, 'calcified granuloma'),
#   Text(0.9450799315506884, 0.5628711424297272, 'metastasis of ovarian cancer'),
#   Text(0.935792896034828, 0.5781796050802466, 'inflammatory mass'),
#   Text(-1.0854591705685532, 0.17826494054813075, 'lung cancer'),
#   Text(0.7017179407514673, -0.8471079810906755, 'unknown'),
#   Text(0.7017179407514673, -0.8471079810906755, 'susp. inflammatory mass'),
#   Text(0.7154133233772676, -0.8355739205685475, 'lung cancer(adenosquamous carcinoma)'),
#   Text(0.7289191521834739, -0.8238184688267954, 'pneumonia'),
#   Text(0.7422318487052265, -0.8118447405554968, 'metastasis of uterine cancer'),
#   Text(0.7553478856494322, -0.7996559082786373, 'granuloma'),
#   Text(0.7682637878293438, -0.7872552015135302, 'lung cancer(large cell carcinoma)'),
#   Text(0.7809761330853331, -0.774645905915135, 'organizing pneumonia'),
#   Text(1.0101689264169282, -0.4353834403163155, 'lung cancer(adenocarcinoma)'),
#   Text(1.0994171267668211, -0.03580476744495756, 'hamartoma'),
#   Text(1.0994171267668211, -0.03580476744495756, 'Inflammatory mass'),
#   Text(1.0994171267668211, -0.03580476744495756, 'susp.tuberculoma'),
#   Text(1.0998542704670922, -0.017904852283692266, 'susp. lung metastasis')],
#  [Text(0.6, 0.0, '0%'),
#   Text(0.6, 0.0, '0%'),
#   Text(0.6, 0.0, '0%'),
#   Text(0.6, 0.0, '0%'),
#   Text(0.5961092570907071, 0.06821842574235543, '4%'),
#   Text(0.574429323395191, 0.17329440967250784, '2%'),
#   Text(0.5619367794777581, 0.21030229639774584, '0%'),
#   Text(0.5619367794777581, 0.21030229639774584, '0%'),
#   Text(0.5619367794777581, 0.21030229639774584, '0%'),
#   Text(0.5584392522368802, 0.21942105997627956, '1%'),
#   Text(0.5547937625667126, 0.22848168639317687, '0%'),
#   Text(0.5470627984793587, 0.2464189410737991, '1%'),
#   Text(0.5343820417252114, 0.2728293119912053, '1%'),
#   Text(0.5252183953245563, 0.2900786741777101, '1%'),
#   Text(0.5204272153390168, 0.2985892053214192, '0%'),
#   Text(0.5204272153390168, 0.2985892053214192, '0%'),
#   Text(0.5154981444821937, 0.30702062314348755, '1%'),
#   Text(0.5104324887462697, 0.31537069368013443, '0%'),
#   Text(-0.5920686384919381, 0.09723542211716223, '77%'),
#   Text(0.38275524040989123, -0.46205889877673206, '0%'),
#   Text(0.38275524040989123, -0.46205889877673206, '0%'),
#   Text(0.39022544911487317, -0.4557675930373895, '1%'),
#   Text(0.3975922648273494, -0.44935552845097926, '0%'),
#   Text(0.40485373565739624, -0.44282440393936184, '1%'),
#   Text(0.412007937626963, -0.43617594997016573, '0%'),
#   Text(0.4190529751796421, -0.42941192809828915, '1%'),
#   Text(0.4259869816829089, -0.4225341304991645, '0%'),
#   Text(0.5510012325910517, -0.23748187653617206, '12%'),
#   Text(0.5996820691455388, -0.019529873151795028, '0%'),
#   Text(0.5996820691455388, -0.019529873151795028, '0%'),
#   Text(0.5996820691455388, -0.019529873151795028, '0%'),
#   Text(0.5999205111638684, -0.009766283063832143, '1%')])

# %%
#Q2B
lstitr=0   
for i in lst:
    itr=0
    for u in df['diagnosis']:
        if i==u:
            if df['state'][itr]=='benign':
                occ+=1
        itr+=1  
    benList[lstitr]=occ
    lstitr+=1
    occ=0

plt.pyplot.pie(benList,autopct='%1.0f%%',labels=lst)
# Out:
# ([<matplotlib.patches.Wedge at 0x2c2a1e77490>,
#   <matplotlib.patches.Wedge at 0x2c2a1e77c10>,
#   <matplotlib.patches.Wedge at 0x2c2a1e84370>,
#   <matplotlib.patches.Wedge at 0x2c2a1e84a90>,
#   <matplotlib.patches.Wedge at 0x2c2a1e921f0>,
#   <matplotlib.patches.Wedge at 0x2c2a1e92910>,
#   <matplotlib.patches.Wedge at 0x2c2a1e92fd0>,
#   <matplotlib.patches.Wedge at 0x2c2a1e9e730>,
#   <matplotlib.patches.Wedge at 0x2c2a1e9ee50>,
#   <matplotlib.patches.Wedge at 0x2c2a1eaa5b0>,
#   <matplotlib.patches.Wedge at 0x2c2a1e54370>,
#   <matplotlib.patches.Wedge at 0x2c2a1eb7430>,
#   <matplotlib.patches.Wedge at 0x2c2a1eb7b50>,
#   <matplotlib.patches.Wedge at 0x2c2a1ec42b0>,
#   <matplotlib.patches.Wedge at 0x2c2a1ec49d0>,
#   <matplotlib.patches.Wedge at 0x2c2a1ed1130>,
#   <matplotlib.patches.Wedge at 0x2c2a1ed1850>,
#   <matplotlib.patches.Wedge at 0x2c2a1ed1f70>,
#   <matplotlib.patches.Wedge at 0x2c2a1edf6d0>,
#   <matplotlib.patches.Wedge at 0x2c2a1edfdf0>,
#   <matplotlib.patches.Wedge at 0x2c2a1eeb550>,
#   <matplotlib.patches.Wedge at 0x2c2a1eebc70>,
#   <matplotlib.patches.Wedge at 0x2c2a1efa3d0>,
#   <matplotlib.patches.Wedge at 0x2c2a1efaaf0>,
#   <matplotlib.patches.Wedge at 0x2c2a1f07250>,
#   <matplotlib.patches.Wedge at 0x2c2a1f07970>,
#   <matplotlib.patches.Wedge at 0x2c2a1f130d0>,
#   <matplotlib.patches.Wedge at 0x2c2a1f137f0>,
#   <matplotlib.patches.Wedge at 0x2c2a1f13f10>,
#   <matplotlib.patches.Wedge at 0x2c2a1f22670>,
#   <matplotlib.patches.Wedge at 0x2c2a1f22d90>,
#   <matplotlib.patches.Wedge at 0x2c2a1f304f0>],
#  [Text(1.0981389740706715, 0.06395931227751966, 'susp. hamartoma'),
#   Text(0.656874465406343, 0.8823355012109234, 'tuberculoma'),
#   Text(-0.3154835212675114, 1.0537884739399326, 'Cryptococcosis'),
#   Text(-0.49367906711618187, 0.9829959199769329, 'organiging pneumonia'),
#   Text(-0.5499999702695112, 0.9526279613277877, 'lung cancer(bronchioloalveolar cell carcinoma)'),
#   Text(-0.5499999702695112, 0.9526279613277877, 'metastasis of colon cancer'),
#   Text(-0.6568744241012363, 0.8823355319614354, 'lung abscess'),
#   Text(-0.8426488672029964, 0.7070663947618406, 'pulmonary hematoma'),
#   Text(-1.0100377060483294, 0.4356877693493684, 'pulmonary tuberculosis'),
#   Text(-1.0703493512602231, 0.2536774847258217, 'lung canceror metastasis'),
#   Text(-1.0832885235940588, 0.19101302219849933, 'susp. sclerosing hemangioma'),
#   Text(-1.0925621904163443, 0.12770223205817494, 'lung cancer(squamous cell carcinoma)'),
#   Text(-1.0925621904163443, 0.12770223205817494, 'metastatic lung cancer'),
#   Text(-1.0925621904163443, 0.12770223205817494, 'lung cancer(small cell carcinoma)'),
#   Text(-1.0999999999999999, 2.5747358557800545e-08, 'sclerosing hemangioma'),
#   Text(-1.0832885325360226, -0.19101297148610266, 'calcified granuloma'),
#   Text(-1.0703493631357222, -0.2536774346191518, 'metastasis of ovarian cancer'),
#   Text(-0.9829959141992366, -0.49367907862052174, 'inflammatory mass'),
#   Text(-0.8426489003031624, -0.7070663553145993, 'lung cancer'),
#   Text(-0.6568744654063434, -0.882335501210923, 'unknown'),
#   Text(-0.3154835705989096, -1.053788459171082, 'susp. inflammatory mass'),
#   Text(-0.19101300952040007, -1.08328852582955, 'lung cancer(adenosquamous carcinoma)'),
#   Text(-0.12770221927154327, -1.0925621919108874, 'pneumonia'),
#   Text(-0.06395932512941892, -1.0981389733221336, 'metastasis of uterine cancer'),
#   Text(0.4356877338869101, -1.010037721345341, 'granuloma'),
#   Text(0.8426488837530796, -0.7070663750382202, 'lung cancer(large cell carcinoma)'),
#   Text(0.8823355088985513, -0.6568744550800667, 'organizing pneumonia'),
#   Text(0.9190365899341549, -0.6044598798615175, 'lung cancer(adenocarcinoma)'),
#   Text(0.9829959026438435, -0.4936791016292016, 'hamartoma'),
#   Text(1.070349357197973, -0.25367745967248734, 'Inflammatory mass'),
#   Text(1.0981389740706715, -0.06395931227751976, 'susp.tuberculoma'),
#   Text(1.1, -2.6942229581241775e-16, 'susp. lung metastasis')],
#  [Text(0.598984894947639, 0.034886897605919814, '2%'),
#   Text(0.3582951629489143, 0.4812739097514127, '26%'),
#   Text(-0.17208192069136985, 0.574793713058145, '4%'),
#   Text(-0.26927949115428096, 0.5361795927146906, '2%'),
#   Text(-0.29999998378336973, 0.5196152516333387, '0%'),
#   Text(-0.29999998378336973, 0.5196152516333387, '0%'),
#   Text(-0.35829514041885613, 0.48127392652441925, '4%'),
#   Text(-0.45962665483799797, 0.385672578961004, '4%'),
#   Text(-0.5509296578445433, 0.23764787419056457, '6%'),
#   Text(-0.5838269188692126, 0.13836953712317546, '0%'),
#   Text(-0.5908846492331229, 0.10418892119918144, '2%'),
#   Text(-0.5959430129543696, 0.06965576294082268, '0%'),
#   Text(-0.5959430129543696, 0.06965576294082268, '0%'),
#   Text(-0.5959430129543696, 0.06965576294082268, '0%'),
#   Text(-0.5999999999999999, 1.4044013758800295e-08, '4%'),
#   Text(-0.5908846541105578, -0.10418889353787418, '2%'),
#   Text(-0.5838269253467575, -0.13836950979226462, '0%'),
#   Text(-0.5361795895632199, -0.26927949742937546, '7%'),
#   Text(-0.459626672892634, -0.3856725574443269, '0%'),
#   Text(-0.35829516294891456, -0.4812739097514125, '7%'),
#   Text(-0.1720819475994052, -0.5747937050024083, '4%'),
#   Text(-0.10418891428385457, -0.5908846504524817, '0%'),
#   Text(-0.06965575596629632, -0.5959430137695749, '2%'),
#   Text(-0.03488690461604668, -0.5989848945393456, '0%'),
#   Text(0.2376478548474055, -0.5509296661883678, '15%'),
#   Text(0.4596266638653161, -0.38567256820266554, '0%'),
#   Text(0.4812739139446643, -0.3582951573164, '2%'),
#   Text(0.5012926854186299, -0.3297053890153731, '0%'),
#   Text(0.5361795832602783, -0.26927950997956446, '4%'),
#   Text(0.5838269221079851, -0.13836952345772036, '4%'),
#   Text(0.598984894947639, -0.03488689760591987, '2%'),
#   Text(0.6, -1.4695761589768238e-16, '0%')])

# %%
#Q3A
Mlist=[0]*len(lst)
Flist=[0]*len(lst)
lstitr=0   
for i in lst:
    itr=0
    for u in df['diagnosis']:
        if i==u:
            if df['gender'][itr]=='Male':
                occ+=1
        itr+=1  
    Mlist[lstitr]=occ
    lstitr+=1
    occ=0

plt.pyplot.pie(Mlist,autopct='%1.0f%%',labels=lst)
# Out:
# ([<matplotlib.patches.Wedge at 0x2c2a206e280>,
#   <matplotlib.patches.Wedge at 0x2c2a206ea60>,
#   <matplotlib.patches.Wedge at 0x2c2a20791f0>,
#   <matplotlib.patches.Wedge at 0x2c2a2079910>,
#   <matplotlib.patches.Wedge at 0x2c2a2079fd0>,
#   <matplotlib.patches.Wedge at 0x2c2a2082790>,
#   <matplotlib.patches.Wedge at 0x2c2a2082eb0>,
#   <matplotlib.patches.Wedge at 0x2c2a208e610>,
#   <matplotlib.patches.Wedge at 0x2c2a208ed30>,
#   <matplotlib.patches.Wedge at 0x2c2a2098490>,
#   <matplotlib.patches.Wedge at 0x2c2a1d34ca0>,
#   <matplotlib.patches.Wedge at 0x2c2a20a42e0>,
#   <matplotlib.patches.Wedge at 0x2c2a20a4a00>,
#   <matplotlib.patches.Wedge at 0x2c2a20ae160>,
#   <matplotlib.patches.Wedge at 0x2c2a20ae880>,
#   <matplotlib.patches.Wedge at 0x2c2a20aefa0>,
#   <matplotlib.patches.Wedge at 0x2c2a20bc700>,
#   <matplotlib.patches.Wedge at 0x2c2a20bce20>,
#   <matplotlib.patches.Wedge at 0x2c2a20c9580>,
#   <matplotlib.patches.Wedge at 0x2c2a20c9ca0>,
#   <matplotlib.patches.Wedge at 0x2c2a20d7400>,
#   <matplotlib.patches.Wedge at 0x2c2a20d7b20>,
#   <matplotlib.patches.Wedge at 0x2c2a20e4280>,
#   <matplotlib.patches.Wedge at 0x2c2a20e49a0>,
#   <matplotlib.patches.Wedge at 0x2c2a20f1100>,
#   <matplotlib.patches.Wedge at 0x2c2a20f1820>,
#   <matplotlib.patches.Wedge at 0x2c2a20f1f40>,
#   <matplotlib.patches.Wedge at 0x2c2a20fd6a0>,
#   <matplotlib.patches.Wedge at 0x2c2a20fddc0>,
#   <matplotlib.patches.Wedge at 0x2c2a210c520>,
#   <matplotlib.patches.Wedge at 0x2c2a210cc40>,
#   <matplotlib.patches.Wedge at 0x2c2a21193a0>],
#  [Text(1.0996166960164684, 0.02903656043380658, 'susp. hamartoma'),
#   Text(1.053942569888111, 0.31496834662810846, 'tuberculoma'),
#   Text(0.9501987245045059, 0.5541862357998528, 'Cryptococcosis'),
#   Text(0.9352388362466554, 0.579075400251126, 'organiging pneumonia'),
#   Text(0.8689924786539237, 0.6744272177506704, 'lung cancer(bronchioloalveolar cell carcinoma)'),
#   Text(0.793064719668976, 0.7622652756202193, 'metastasis of colon cancer'),
#   Text(0.7517306961630227, 0.8030572585104112, 'lung abscess'),
#   Text(0.7083014641641565, 0.8416109765580011, 'pulmonary hematoma'),
#   Text(0.6156470599881684, 0.9115803297175322, 'pulmonary tuberculosis'),
#   Text(0.5415956711480091, 0.9574310048216204, 'lung canceror metastasis'),
#   Text(0.5415956711480091, 0.9574310048216204, 'susp. sclerosing hemangioma'),
#   Text(0.49031215271474704, 0.9846796397307251, 'lung cancer(squamous cell carcinoma)'),
#   Text(0.4376620462310169, 1.0091837955936864, 'metastatic lung cancer'),
#   Text(0.4108702427079847, 1.0203850467627806, 'lung cancer(small cell carcinoma)'),
#   Text(0.3837920970017805, 1.0308751749261285, 'sclerosing hemangioma'),
#   Text(0.356446480314433, 1.0406468693420707, 'calcified granuloma'),
#   Text(0.3288524502528666, 1.0496933199571608, 'metastasis of ovarian cancer'),
#   Text(0.2729962326492544, 1.0655857811360447, 'inflammatory mass'),
#   Text(-1.075558150347803, -0.23059632525348836, 'lung cancer'),
#   Text(0.6394956046825379, -0.8950113807051369, 'unknown'),
#   Text(0.6628982690753222, -0.8778188223414566, 'susp. inflammatory mass'),
#   Text(0.7083016562325725, -0.8416108149128045, 'lung cancer(adenosquamous carcinoma)'),
#   Text(0.7302707366349225, -0.8226205997996208, 'pneumonia'),
#   Text(0.7302707366349225, -0.8226205997996208, 'metastasis of uterine cancer'),
#   Text(0.8508870584872292, -0.6971307005855866, 'granuloma'),
#   Text(0.964496521361463, -0.5289106354400873, 'lung cancer(large cell carcinoma)'),
#   Text(0.9781220216080985, -0.5032666399089918, 'organizing pneumonia'),
#   Text(1.0618895591420647, -0.28703756580815615, 'lung cancer(adenocarcinoma)'),
#   Text(1.0984670644452033, -0.05805263412747103, 'hamartoma'),
#   Text(1.0984670644452033, -0.05805263412747103, 'Inflammatory mass'),
#   Text(1.0996167026430248, -0.02903630948453912, 'susp.tuberculoma'),
#   Text(1.0999999999999714, 2.5103674179108196e-07, 'susp. lung metastasis')],
#  [Text(0.5997909250998917, 0.015838123872985405, '1%'),
#   Text(0.5748777653935151, 0.17180091634260458, '8%'),
#   Text(0.5182902133660942, 0.30228340134537424, '0%'),
#   Text(0.5101302743163575, 0.31585930922788685, '1%'),
#   Text(0.4739958974475947, 0.36786939150036563, '3%'),
#   Text(0.43258075618307773, 0.41578105942921045, '1%'),
#   Text(0.4100349251798305, 0.4380312319147697, '1%'),
#   Text(0.38634625318044896, 0.45906053266800056, '1%'),
#   Text(0.33580748726627363, 0.4972256343913812, '3%'),
#   Text(0.2954158206261867, 0.5222350935390656, '0%'),
#   Text(0.2954158206261867, 0.5222350935390656, '0%'),
#   Text(0.26744299238986197, 0.5370979853076682, '2%'),
#   Text(0.23872475248964556, 0.5504638885056471, '0%'),
#   Text(0.22411104147708258, 0.5565736618706075, '1%'),
#   Text(0.20934114381915297, 0.5622955499597064, '0%'),
#   Text(0.1944253528987816, 0.5676255650956749, '1%'),
#   Text(0.17937406377429083, 0.5725599927039058, '0%'),
#   Text(0.14890703599050237, 0.581228607892388, '2%'),
#   Text(-0.5866680820078926, -0.12577981377463002, '63%'),
#   Text(0.3488157843722934, -0.4881880258391655, '0%'),
#   Text(0.36158087404108485, -0.4788102667317035, '1%'),
#   Text(0.38634635794503946, -0.45906044449789335, '1%'),
#   Text(0.39832949270995766, -0.44870214534524766, '0%'),
#   Text(0.39832949270995766, -0.44870214534524766, '0%'),
#   Text(0.4641202137203068, -0.3802531094103199, '5%'),
#   Text(0.5260890116517071, -0.2884967102400476, '1%'),
#   Text(0.5335211026953264, -0.2745090763139955, '0%'),
#   Text(0.5792124868047626, -0.15656594498626697, '7%'),
#   Text(0.5991638533337471, -0.03166507316043874, '0%'),
#   Text(0.5991638533337471, -0.03166507316043874, '0%'),
#   Text(0.5997909287143771, -0.015837986991566792, '1%'),
#   Text(0.5999999999999843, 1.3692913188604468e-07, '0%')])

# %%
#Q3B
lstitr=0   
for i in lst:
    itr=0
    for u in df['diagnosis']:
        if i==u:
            if df['gender'][itr]=='Female':
                occ+=1
        itr+=1  
    Flist[lstitr]=occ
    lstitr+=1
    occ=0

plt.pyplot.pie(Flist,autopct='%1.0f%%',labels=lst)
# Out:
# ([<matplotlib.patches.Wedge at 0x2c2a1f82460>,
#   <matplotlib.patches.Wedge at 0x2c2a1f82a90>,
#   <matplotlib.patches.Wedge at 0x2c2a1f921f0>,
#   <matplotlib.patches.Wedge at 0x2c2a1f92910>,
#   <matplotlib.patches.Wedge at 0x2c2a1f92fd0>,
#   <matplotlib.patches.Wedge at 0x2c2a1f9f7c0>,
#   <matplotlib.patches.Wedge at 0x2c2a1f9fee0>,
#   <matplotlib.patches.Wedge at 0x2c2a1faa640>,
#   <matplotlib.patches.Wedge at 0x2c2a1faad60>,
#   <matplotlib.patches.Wedge at 0x2c2a1fb94c0>,
#   <matplotlib.patches.Wedge at 0x2c2a1f591f0>,
#   <matplotlib.patches.Wedge at 0x2c2a1fc6310>,
#   <matplotlib.patches.Wedge at 0x2c2a1fc6a30>,
#   <matplotlib.patches.Wedge at 0x2c2a1fd4190>,
#   <matplotlib.patches.Wedge at 0x2c2a1fd48b0>,
#   <matplotlib.patches.Wedge at 0x2c2a1fd4fd0>,
#   <matplotlib.patches.Wedge at 0x2c2a1fe1730>,
#   <matplotlib.patches.Wedge at 0x2c2a1fe1e50>,
#   <matplotlib.patches.Wedge at 0x2c2a1fee5b0>,
#   <matplotlib.patches.Wedge at 0x2c2a1feecd0>,
#   <matplotlib.patches.Wedge at 0x2c2a1ffb430>,
#   <matplotlib.patches.Wedge at 0x2c2a1ffbb50>,
#   <matplotlib.patches.Wedge at 0x2c2a200b2b0>,
#   <matplotlib.patches.Wedge at 0x2c2a200b9d0>,
#   <matplotlib.patches.Wedge at 0x2c2a2017130>,
#   <matplotlib.patches.Wedge at 0x2c2a2017850>,
#   <matplotlib.patches.Wedge at 0x2c2a2017f70>,
#   <matplotlib.patches.Wedge at 0x2c2a20256d0>,
#   <matplotlib.patches.Wedge at 0x2c2a2025df0>,
#   <matplotlib.patches.Wedge at 0x2c2a2032550>,
#   <matplotlib.patches.Wedge at 0x2c2a2032c70>,
#   <matplotlib.patches.Wedge at 0x2c2a203f3d0>],
#  [Text(1.1, 0.0, 'susp. hamartoma'),
#   Text(1.091727488058581, 0.13465174271913782, 'tuberculoma'),
#   Text(1.0526343693054299, 0.3193131449799086, 'Cryptococcosis'),
#   Text(1.035698471701323, 0.3705788387314421, 'organiging pneumonia'),
#   Text(0.9943882224357877, 0.4703106027733103, 'lung cancer(bronchioloalveolar cell carcinoma)'),
#   Text(0.8993432944667421, 0.6333890105596299, 'metastasis of colon cancer'),
#   Text(0.8329297311571331, 0.7184901272491545, 'lung abscess'),
#   Text(0.7966717912466138, 0.7584945992107736, 'pulmonary hematoma'),
#   Text(0.7778174593052024, 0.7778174593052024, 'pulmonary tuberculosis'),
#   Text(0.7584945992107737, 0.7966717912466137, 'lung canceror metastasis'),
#   Text(0.7184901272491546, 0.8329297311571331, 'susp. sclerosing hemangioma'),
#   Text(0.6978326125800101, 0.8503114986990107, 'lung cancer(squamous cell carcinoma)'),
#   Text(0.6767547496386895, 0.867181070389267, 'metastatic lung cancer'),
#   Text(0.6552692349416769, 0.8835282846287094, 'lung cancer(small cell carcinoma)'),
#   Text(0.6111272563215626, 0.9146165735327998, 'sclerosing hemangioma'),
#   Text(0.5655130186125439, 0.9435014710002994, 'calcified granuloma'),
#   Text(0.5421880114527625, 0.9570956902195825, 'metastasis of ovarian cancer'),
#   Text(0.47031060277331044, 0.9943882224357877, 'inflammatory mass'),
#   Text(-1.088094160961259, 0.161403521900898, 'lung cancer'),
#   Text(0.21459935421774115, -1.0788638084435536, 'unknown'),
#   Text(0.34504991443878025, -1.0444809986523405, 'susp. inflammatory mass'),
#   Text(0.3705788387314416, -1.0356984717013231, 'lung cancer(adenosquamous carcinoma)'),
#   Text(0.3958845401884864, -1.026292078718213, 'pneumonia'),
#   Text(0.44576544540548907, -1.0056307312738837, 'metastasis of uterine cancer'),
#   Text(0.5185364105085973, -0.9701133907831906, 'granuloma'),
#   Text(0.5655130186125438, -0.9435014710002996, 'lung cancer(large cell carcinoma)'),
#   Text(0.5884973818758067, -0.929338921774678, 'organizing pneumonia'),
#   Text(0.8993432944667421, -0.6333890105596298, 'lung cancer(adenocarcinoma)'),
#   Text(1.0788638084435533, -0.21459935421774162, 'hamartoma'),
#   Text(1.0947031993394167, -0.10781885436251656, 'Inflammatory mass'),
#   Text(1.0986750018256897, -0.053974441760159905, 'susp.tuberculoma'),
#   Text(1.0996687005658248, -0.026995351375203695, 'susp. lung metastasis')],
#  [Text(0.6, 0.0, '0%'),
#   Text(0.595487720759226, 0.07344640511952971, '4%'),
#   Text(0.5741642014393252, 0.1741708063526774, '2%'),
#   Text(0.5649264391098124, 0.20213391203533201, '0%'),
#   Text(0.542393575874066, 0.25653305605816923, '3%'),
#   Text(0.4905508878909502, 0.3454849148507072, '2%'),
#   Text(0.4543253079038907, 0.391903705772266, '1%'),
#   Text(0.4345482497708802, 0.4137243268422401, '1%'),
#   Text(0.4242640687119285, 0.4242640687119285, '0%'),
#   Text(0.41372432684224014, 0.43454824977088014, '1%'),
#   Text(0.39190370577226613, 0.4543253079038907, '1%'),
#   Text(0.38063597049818726, 0.46380627201764213, '0%'),
#   Text(0.36913895434837607, 0.4730078565759637, '1%'),
#   Text(0.3574195826954601, 0.4819245188883869, '0%'),
#   Text(0.33334213981176136, 0.4988817673815271, '2%'),
#   Text(0.308461646515933, 0.5146371660001633, '0%'),
#   Text(0.29573891533787044, 0.5220521946652268, '1%'),
#   Text(0.2565330560581693, 0.542393575874066, '2%'),
#   Text(-0.5935059059788685, 0.08803828467321707, '58%'),
#   Text(0.11705419320967697, -0.5884711682419382, '3%'),
#   Text(0.18820904423933468, -0.569716908355822, '1%'),
#   Text(0.20213391203533176, -0.5649264391098126, '0%'),
#   Text(0.21593702192099257, -0.5597956793008434, '1%'),
#   Text(0.243144788402994, -0.5485258534221183, '1%'),
#   Text(0.28283804209559854, -0.529152758609013, '2%'),
#   Text(0.30846164651593294, -0.5146371660001633, '0%'),
#   Text(0.32099857193225817, -0.5069121391498244, '1%'),
#   Text(0.4905508878909502, -0.34548491485070715, '12%'),
#   Text(0.5884711682419381, -0.11705419320967722, '2%'),
#   Text(0.5971108360033182, -0.058810284197736304, '2%'),
#   Text(0.5992772737231035, -0.029440604596450853, '0%'),
#   Text(0.5998192912177225, -0.014724737113747468, '1%')])
